# %% [markdown]
# ### Solves the 2D Wave equation with MDM and position Verlet algorithm

# %%
import numpy as np
from core import *

# %%
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
from matplotlib import animation, rcParams
from IPython.display import HTML

# %%
rcParams['animation.html'] = 'html5'

# %%
# Spatial discretization

# Order of accuracy
k = 2
# Number of cells along the x-axis
m = 50
# Number of cells along the y-axis
n = m
# West
a = 0
# East
b = 1
# South
c = 0
# North
d = 1

# Step length along the x-axis
dx = (b - a) / m
# Step length along the y-axis
dy = (d - c) / n

# 2D Staggered grid
xgrid = np.append(np.insert(np.arange(a + dx/2., b, dx), 0, a), b)
ygrid = np.append(np.insert(np.arange(c + dy/2., d, dy), 0, c), d)

X, Y = np.meshgrid(xgrid, ygrid, indexing='ij')

# Mimetic operator (Laplacian)
L = lap2D(k, m, dx, n, dy)

# Dirichlet BC
L = L + robinBC2D(k, m, dx, n, dy, 1, 0)
I = interpol2D(m, n, 0.5, 0.5)
I2 = interpolD2D(m, n, 0.5, 0.5)

# Wave propagation speed
c = 1.  # (T/p) Tension over density

# "Force" function
def F(x, c):
    return (c**2) * L @ x  # c^2 DivGrad x

# Simulation time
TIME = 1.

# Temporal discretization based on CFL condition
dt = dx / (2 * c)  #  dt = h on Young's paper

# Initial condition
# Initial position of particles
def ICU(x, y):
    return np.sin(np.pi * x) * np.sin(np.pi * y)
# Initial velocity of particles
def ICV(x, y):
    return np.zeros(2*m*n+m+n)

uold = ICU(X, Y)
vold = ICV(X, Y)
uold = np.reshape(uold, (m+2) * (n+2))
theta = 1. / (2. - 2.**(1./3.))  # From Peter Young's paper

# Premultiply I and I2
I = dt * I
I2 = 0.5 * dt * I2

Nt = int(TIME / dt)
solution = np.zeros((m+2, n+2, Nt))

# Time integration loop
for t in range(0, Nt):
    # Apply "position Verlet" algorithm (2nd-order in time)
    uold = uold + I2 @ vold
    vnew = vold + I @ F(uold, c)
    unew = uold + I2 @ vnew
    
    # Update
    uold = unew.copy()
    vold = vnew.copy()
    solution[..., t] = np.reshape(unew, (m+2, n+2))
# Out:
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/div1D.py:53: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   D[i, j:j+k] = coeffs
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/div2D.py:27: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   Im[1:m+1, :] = sparse.eye(m, m, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/div2D.py:28: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   In[1:n+1, :] = sparse.eye(n, n, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/grad1D.py:52: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   G[i, j:j+k] = coeffs
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/grad1D.py:72: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   A[i, 0:q] = coeffs
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/grad1D.py:78: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   G[0:p, 0:q] = A
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/grad1D.py:95: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   G[n_rows-p:n_rows, n_cols-q:n_cols] = A
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/grad2D.py:27: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   Im[1:m+1, :] = sparse.eye(m, m, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/grad2D.py:28: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   In[1:n+1, :] = sparse.eye(n, n, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/robinBC1D.py:25: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   A[0, 0] = a
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/robinBC1D.py:26: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   A[-1, -1] = a
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/robinBC1D.py:29: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   B[0, 0] = -b
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/robinBC1D.py:30: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   B[-1, -1] = b
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpol1D.py:27: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   I[0, 0] = 1.
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpol1D.py:28: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   I[-1, -1] = 1.
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpol1D.py:37: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   I[i, j:j+2] = avg
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpol2D.py:26: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   Im[1:m+1, :] = sparse.eye(m, m, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpol2D.py:27: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   In[1:n+1, :] = sparse.eye(n, n, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpolD1D.py:27: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   I[0, 0] = 1.
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpolD1D.py:28: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   I[-1, -1] = 1.
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpolD1D.py:37: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   I[i, j:j+2] = avg
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpolD2D.py:26: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   Im[1:m+1, :] = sparse.eye(m, m, dtype=np.float, format='csr')
# /Users/nutrik/Documents/Science/scodes/Python/pymole/core/interpolD2D.py:27: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   In[1:n+1, :] = sparse.eye(n, n, dtype=np.float, format='csr')

# %%
def animate_wave2d(solution):
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111, projection='3d')

    # Setting the axes properties
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlim3d([-1.0, 1.0])
    ax.set_zlabel('U(X,Y)')
    x, y = np.meshgrid(xgrid, ygrid)
    surface = [ax.plot_surface(x, y, solution[:, :, 0], color='0.75', rstride=1, cstride=1, vmin=-1, vmax=1)]
    plt.close()

    def update_plot(frame_number, data, surface):
        surface[0].remove()
        surface[0] = ax.plot_surface(x, y, data[:, :, frame_number], cmap="coolwarm", vmin=-1, vmax=1)

    return animation.FuncAnimation(fig, update_plot, frames=Nt, fargs=(solution, surface), interval=50)

# %%
anim = animate_wave2d(solution)

# %%
anim
# Out:
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
